# %%
import pandas as pd

from sklearn.ensemble import IsolationForest

# %%
#path_import = "/Users/ppx/Desktop/"
#import_file = "the_result_file.csv"
path_mouse = 'mouse.txt'

# %% [markdown]
# # Mise en forme donnée

# %%
data_mouse = pd.read_csv(path_mouse, delimiter=' ',header=None, na_values='?')

# %%
data_mouse.describe()
# Out:
#                 0           1
# count  500.000000  500.000000
# mean     0.505892    0.599706
# std      0.191763    0.156863
# min      0.040555    0.138940
# 25%      0.328481    0.469010
# 50%      0.504702    0.629494
# 75%      0.681430    0.735364
# max      0.916030    0.897028

# %%
plt.scatter(data_mouse[0], data_mouse[1])
plt.show()

# %%
clf = IsolationForest(n_estimators=1000, 
                      max_samples=500, 
                      contamination=0.02, 
                      max_features=1.01, 
                      bootstrap=False,  
                      verbose=0)
clf.fit(data_mouse)
predicton = clf.predict(data_mouse)

# %%
plt.title("IsolationForest")
b2 = plt.scatter(data_mouse[0], data_mouse[ 1], c=predicton, s=20)
plt.axis('tight')
plt.xlim((0, 1))
plt.ylim((0, 1))

plt.show()

# %% [markdown]
# Certes, on a boosté les paramêtres car on savait ce que l'on voulit obtenir
